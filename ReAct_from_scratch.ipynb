# %%
import os
import math
from dotenv import load_dotenv

load_dotenv()

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage, ToolMessage

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.prebuilt import create_react_agent
from langchain_tavily import TavilySearch
from langchain_community.tools import DuckDuckGoSearchRun

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # loads from .env in current directory

print(os.getenv("GROQ_API_KEY"))  # should print your key, not None
# Out:
# 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

# %%
# Cell 2 — Verify keys are loaded
groq_key = os.getenv("GROQ_API_KEY")
tavily_key = os.getenv("TAVILY_API_KEY")

print(f"GROQ key loaded: {groq_key[:8]}..." if groq_key else "❌ GROQ key missing")
print(f"TAVILY key loaded: {tavily_key[:8]}..." if tavily_key else "❌ TAVILY key missing")
# Out:
# GROQ key loaded: gsk_7JuE...
# TAVILY key loaded: tvly-dev...

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")
tools = [DuckDuckGoSearchRun()]

# %%
from langchain.agents import create_agent
#agent = create_agent(llm, tools)
# Cell 6 — correct function
from langgraph.prebuilt import create_react_agent
from langchain_core.tools import tool

@tool
def search(query: str) -> str:
    """Search the web for current information."""
    return DuckDuckGoSearchRun().run(query)

agent = create_agent(llm, [search])

# %%
# Cell 4 — Run it
result = agent.invoke({
    "messages": [{"role": "user", "content": "What's the news on IPL Cricket?"}]
})

for msg in result["messages"]:
    print(f"[{msg.type}]: {msg.content}\n")
# Out:
# [human]: What's the news on IPL Cricket?
#
# [ai]:
#
# [tool]: 3 hours ago—Two decades of compounding growth in Indian Premier League cricket media rights are coming to an end, according to a new report from Media Partners Asia. 4 hours ago—Cricket News: The BCCI has barred IPL teams from holding practice sessions on match days in IPL 2026, according to a note sent to team managers. 3 hours ago—The 19th edition of the Indian Premier League (IPL) is all set to begin on March 28, with defending champions Royal Challengers Bengaluru taking on Sunrisers ... 3 hours ago—Media Partners Asia has projected that the value of the IPL's 2028–32 domestic rights could remain broadly flat at around $5.4 billion, pointing to a more ... 4 hours ago—Two decades of compounding growth in Indian Premier League cricket media rights are coming to an end, according to a new report from Media Partners Asia.
#
# ...
